# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayan1598/music-genre-classification-code/blob/main/CNN_BiLSTM_BiGRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/genres_original'

# %%
# Music Genre Classification (CNN + BiLSTM + BiGRU Hybrid)


import os
import random
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization,
    Bidirectional, LSTM, GRU, Reshape, concatenate, Input
)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import joblib


# 🎛 Step 1: Audio Augmentation

def augment_audio(y, sr):
    if random.random() < 0.5:
        y = librosa.effects.pitch_shift(y, sr, n_steps=random.uniform(-2, 2))
    if random.random() < 0.5:
        y = librosa.effects.time_stretch(y, rate=random.uniform(0.8, 1.2))
    if random.random() < 0.5:
        noise = np.random.randn(len(y)) * 0.005
        y = y + noise
    return y



# Step 2: Extract Mel Spectrogram Chunks

def extract_melspectrogram_chunks(y, sr, chunk_duration=4, overlap_duration=2, n_mels=256):
    chunk_samples = int(chunk_duration * sr)
    overlap_samples = int(overlap_duration * sr)
    num_chunks = max(1, int(np.ceil((len(y) - overlap_samples) / (chunk_samples - overlap_samples))))
    features = []

    for i in range(num_chunks):
        start = i * (chunk_samples - overlap_samples)
        end = start + chunk_samples
        chunk = y[start:end]

        if len(chunk) < chunk_samples:
            chunk = np.pad(chunk, (0, chunk_samples - len(chunk)))

        mel_spec = librosa.feature.melspectrogram(
            y=chunk,
            sr=sr,
            n_fft=2048,
            hop_length=512,
            n_mels=n_mels,
            fmin=20,
            fmax=sr // 2
        )
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
        mel_spec_db = librosa.util.normalize(mel_spec_db)
        mel_spec_db = np.expand_dims(mel_spec_db, axis=-1)
        features.append(mel_spec_db)

    return features



# Step 3: Load Dataset

def load_dataset(data_dir, classes):
    X, y = [], []

    for genre in classes:
        genre_dir = os.path.join(data_dir, genre)
        print(f"Processing: {genre}")

        for file in os.listdir(genre_dir):
            if file.endswith('.wav'):
                file_path = os.path.join(genre_dir, file)
                try:
                    y_audio, sr = librosa.load(file_path, sr=None)
                    y_audio = augment_audio(y_audio, sr)
                    features = extract_melspectrogram_chunks(y_audio, sr)

                    for f in features:
                        X.append(f)
                        y.append(genre)

                except Exception as e:
                    print(f" Skipping {file_path}: {e}")

    return np.array(X, dtype=np.float32), np.array(y)



# Step 4: Encode Labels + Split Dataset

def prepare_data(X, y):
    encoder = LabelEncoder()
    y_encoded = encoder.fit_transform(y)
    y_onehot = to_categorical(y_encoded)

    X_train, X_test, y_train, y_test = train_test_split(
        X, y_onehot, test_size=0.2, random_state=42, stratify=y_onehot
    )
    return X_train, X_test, y_train, y_test, encoder


# Step 5: Build CNN + BiLSTM + BiGRU Model

def build_cnn_bilstm_bigru(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # --- CNN Feature Extractor ---
    x = Conv2D(64, (3,3), activation='relu', padding='same', kernel_regularizer=l2(0.001))(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2,2))(x)
    x = Dropout(0.3)(x)

    x = Conv2D(128, (3,3), activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2,2))(x)
    x = Dropout(0.3)(x)

    x = Conv2D(256, (3,3), activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2,2))(x)
    x = Dropout(0.4)(x)

    x = Reshape((-1, 256))(x)

    # Parallel BiLSTM and BiGRU branches
    bilstm_out = Bidirectional(LSTM(128, return_sequences=True))(x)
    bilstm_out = Dropout(0.4)(bilstm_out)
    bilstm_out = Bidirectional(LSTM(64, return_sequences=False))(bilstm_out)
    bilstm_out = Dropout(0.4)(bilstm_out)

    bigru_out = Bidirectional(GRU(128, return_sequences=True))(x)
    bigru_out = Dropout(0.4)(bigru_out)
    bigru_out = Bidirectional(GRU(64, return_sequences=False))(bigru_out)
    bigru_out = Dropout(0.4)(bigru_out)

    #Combine Both
    combined = concatenate([bilstm_out, bigru_out])

    # Dense Layers
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(combined)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    optimizer = Adam(learning_rate=1e-3)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model



# Step 6: Train the Model

def train_hybrid_model(data_dir, classes):
    X, y = load_dataset(data_dir, classes)
    print(f"\n Data Loaded: {X.shape[0]} samples, each shape: {X[0].shape}")

    X_train, X_test, y_train, y_test, encoder = prepare_data(X, y)
    input_shape = X_train.shape[1:]
    num_classes = y_train.shape[1]

    model = build_cnn_bilstm_bigru(input_shape, num_classes)
    model.summary()

    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-6, verbose=1)
    early_stop = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True, verbose=1)

    history = model.fit(
        X_train, y_train,
        epochs=60,
        batch_size=16,
        validation_data=(X_test, y_test),
        callbacks=[lr_scheduler, early_stop]
    )

    test_loss, test_acc = model.evaluate(X_test, y_test)
    print(f"\n Test Accuracy: {test_acc:.3f}")

    return model, history, encoder, X_test, y_test



# Step 7: Evaluation

def evaluate_model(model, X_test, y_test, encoder, classes):
    y_pred = model.predict(X_test)
    y_true_labels = np.argmax(y_test, axis=1)
    y_pred_labels = np.argmax(y_pred, axis=1)

    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    print("\nClassification Report:\n")
    print(classification_report(y_true_labels, y_pred_labels, target_names=classes))

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_norm, annot=True, fmt='.2f', cmap='Blues',
                xticklabels=classes, yticklabels=classes)
    plt.title(' Genre-wise Accuracy Heatmap (Hybrid Model)')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    plt.show()

    acc_per_genre = np.diag(cm_norm)
    plt.figure(figsize=(8, 4))
    sns.barplot(x=classes, y=acc_per_genre, palette='mako')
    plt.title(' Per-Genre Accuracy (Hybrid Model)')
    plt.ylabel('Accuracy')
    plt.xticks(rotation=45)
    plt.ylim(0, 1)
    plt.tight_layout()
    plt.show()



#  Step 8: Save Model + Encoder

def save_model_and_encoder(model, encoder):
    model.save("/content/music_genre_hybrid_model.h5")
    joblib.dump(encoder, "/content/label_encoder.pkl")
    print("\n Hybrid model and encoder saved successfully!")


# ============================================
#  Step 9: Run Everything
# ============================================
data_dir = "/content/drive/MyDrive/genres_original"
classes = ['blues','classical','country','disco','hiphop','jazz','metal','pop','reggae','rock']

model, history, encoder, X_test, y_test = train_hybrid_model(data_dir, classes)
evaluate_model(model, X_test, y_test, encoder, classes)
save_model_and_encoder(model, encoder)
# Out:
# Processing: blues
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00016.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00006.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00007.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00014.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00011.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00008.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00012.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00054.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00036.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00044.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00039.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00049.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00033.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00037.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00030.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00027.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00046.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00041.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00022.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00047.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00018.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00028.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00050.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00032.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00024.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00081.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00071.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00068.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00086.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00064.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00078.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00065.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00059.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00062.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00060.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00076.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00077.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00089.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00069.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00070.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00063.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00074.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00092.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00057.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00096.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00098.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00094.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/blues/blues.00099.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
# Processing: classical
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00022.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00015.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00027.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00024.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00028.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00012.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00000.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00019.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00008.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00011.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00005.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00016.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00018.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00052.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00056.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00057.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00042.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00049.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00037.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00048.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00054.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00065.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00035.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00067.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00045.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00032.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00033.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00085.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00091.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00071.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00095.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00087.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00094.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00093.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00069.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00096.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00079.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00092.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/classical/classical.00089.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
# Processing: country
#  Skipping /content/drive/MyDrive/genres_original/country/country.00003.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00006.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00005.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00004.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00035.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00040.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00034.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00028.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00037.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00024.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00047.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00012.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00041.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00017.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00043.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00042.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00044.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00036.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00020.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00033.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00048.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00029.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00019.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00030.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00011.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00023.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00027.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00039.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00087.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00063.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00061.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00078.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00053.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00065.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00088.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00057.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00073.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00071.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00050.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00068.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00064.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00055.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00058.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00051.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00062.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00093.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00092.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00098.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00096.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00094.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00095.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/country/country.00097.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
# Processing: disco
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00009.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00029.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00005.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00023.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00002.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00020.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00000.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00030.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00011.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00025.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00024.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00003.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00004.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00010.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00031.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00026.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00001.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00008.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00012.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00061.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00050.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00070.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00045.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00069.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00046.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00065.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00051.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00041.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00032.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00039.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00037.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00040.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00060.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00042.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00033.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00082.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00087.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00083.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00077.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00097.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00073.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00093.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00075.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00089.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00085.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00090.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00076.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00092.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00088.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/disco/disco.00086.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
# Processing: hiphop
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00003.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00005.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00004.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00001.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00000.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00008.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00016.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00023.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00020.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00013.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00014.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00061.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00072.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00074.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00070.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00083.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00082.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00068.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00081.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00080.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00091.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00085.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00092.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00098.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00094.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00093.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00090.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00097.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00095.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/hiphop/hiphop.00088.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
# Processing: jazz
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00001.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00018.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00023.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00012.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00017.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00009.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00008.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00021.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00004.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00007.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00014.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00003.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00016.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00032.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00044.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00025.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00033.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00042.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00030.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00026.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00043.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
#  Skipping /content/drive/MyDrive/genres_original/jazz/jazz.00040.wav: pitch_shift() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
# ...
# │ conv2d_2 (Conv2D)   │ (None, 64, 43,    │    295,168 │ dropout_1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 43,    │      1,024 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 21,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 21,    │          0 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 672, 256)  │          0 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 672, 256)  │    394,240 │ reshape[0][0]     │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_2     │ (None, 672, 256)  │    296,448 │ reshape[0][0]     │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 672, 256)  │          0 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 672, 256)  │          0 │ bidirectional_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 128)       │    164,352 │ dropout_3[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_3     │ (None, 128)       │    123,648 │ dropout_5[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ bidirectional_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ bidirectional_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 256)       │          0 │ dropout_4[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    131,584 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 10)        │      2,570 │ dropout_8[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,618,698 (6.17 MB)
#  Trainable params: 1,616,266 (6.17 MB)
#  Non-trainable params: 2,432 (9.50 KB)
# Epoch 1/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 143s 321ms/step - accuracy: 0.1535 - loss: 3.8661 - val_accuracy: 0.1101 - val_loss: 5.9307 - learning_rate: 0.0010
# Epoch 2/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 127s 318ms/step - accuracy: 0.2452 - loss: 3.1979 - val_accuracy: 0.2652 - val_loss: 3.0489 - learning_rate: 0.0010
# Epoch 3/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 126s 315ms/step - accuracy: 0.3204 - loss: 2.7892 - val_accuracy: 0.1920 - val_loss: 3.4945 - learning_rate: 0.0010
# Epoch 4/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 127s 317ms/step - accuracy: 0.4003 - loss: 2.4804 - val_accuracy: 0.4790 - val_loss: 2.2859 - learning_rate: 0.0010
# Epoch 5/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 126s 315ms/step - accuracy: 0.5030 - loss: 2.1666 - val_accuracy: 0.3440 - val_loss: 2.9804 - learning_rate: 0.0010
# Epoch 6/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 126s 314ms/step - accuracy: 0.5370 - loss: 2.0218 - val_accuracy: 0.4847 - val_loss: 2.2449 - learning_rate: 0.0010
# Epoch 7/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 314ms/step - accuracy: 0.5865 - loss: 1.8705 - val_accuracy: 0.2208 - val_loss: 4.1599 - learning_rate: 0.0010
# Epoch 8/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 313ms/step - accuracy: 0.6094 - loss: 1.7460 - val_accuracy: 0.4728 - val_loss: 2.2870 - learning_rate: 0.0010
# Epoch 9/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 127s 318ms/step - accuracy: 0.6528 - loss: 1.6058 - val_accuracy: 0.5116 - val_loss: 1.9466 - learning_rate: 0.0010
# Epoch 10/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 140s 313ms/step - accuracy: 0.6743 - loss: 1.5318 - val_accuracy: 0.3984 - val_loss: 2.6883 - learning_rate: 0.0010
# Epoch 11/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.7021 - loss: 1.4463 - val_accuracy: 0.5879 - val_loss: 1.8661 - learning_rate: 0.0010
# Epoch 12/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 312ms/step - accuracy: 0.6763 - loss: 1.4768 - val_accuracy: 0.4103 - val_loss: 3.0631 - learning_rate: 0.0010
# Epoch 13/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.7063 - loss: 1.4085 - val_accuracy: 0.6079 - val_loss: 1.7403 - learning_rate: 0.0010
# Epoch 14/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.7312 - loss: 1.3745 - val_accuracy: 0.4409 - val_loss: 2.6798 - learning_rate: 0.0010
# Epoch 15/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 310ms/step - accuracy: 0.7389 - loss: 1.3552 - val_accuracy: 0.4759 - val_loss: 2.3059 - learning_rate: 0.0010
# Epoch 16/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 311ms/step - accuracy: 0.7424 - loss: 1.3387 - val_accuracy: 0.6373 - val_loss: 1.8024 - learning_rate: 0.0010
# Epoch 17/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.7382 - loss: 1.3580
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.7382 - loss: 1.3580 - val_accuracy: 0.5879 - val_loss: 2.1326 - learning_rate: 0.0010
# Epoch 18/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.7921 - loss: 1.2081 - val_accuracy: 0.7561 - val_loss: 1.2963 - learning_rate: 5.0000e-04
# Epoch 19/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 311ms/step - accuracy: 0.8079 - loss: 1.0885 - val_accuracy: 0.6748 - val_loss: 1.5359 - learning_rate: 5.0000e-04
# Epoch 20/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 310ms/step - accuracy: 0.8459 - loss: 0.9819 - val_accuracy: 0.7211 - val_loss: 1.3003 - learning_rate: 5.0000e-04
# Epoch 21/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.8571 - loss: 0.9189 - val_accuracy: 0.7011 - val_loss: 1.5278 - learning_rate: 5.0000e-04
# Epoch 22/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.8596 - loss: 0.8794
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 142s 312ms/step - accuracy: 0.8596 - loss: 0.8795 - val_accuracy: 0.6435 - val_loss: 1.7785 - learning_rate: 5.0000e-04
# Epoch 23/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 310ms/step - accuracy: 0.8708 - loss: 0.8460 - val_accuracy: 0.6154 - val_loss: 1.9722 - learning_rate: 2.5000e-04
# Epoch 24/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 312ms/step - accuracy: 0.8913 - loss: 0.7749 - val_accuracy: 0.8499 - val_loss: 0.8744 - learning_rate: 2.5000e-04
# Epoch 25/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 310ms/step - accuracy: 0.9063 - loss: 0.7094 - val_accuracy: 0.7567 - val_loss: 1.2953 - learning_rate: 2.5000e-04
# Epoch 26/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.8968 - loss: 0.7114 - val_accuracy: 0.8343 - val_loss: 0.9404 - learning_rate: 2.5000e-04
# Epoch 27/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 127s 316ms/step - accuracy: 0.9120 - loss: 0.6697 - val_accuracy: 0.8962 - val_loss: 0.7037 - learning_rate: 2.5000e-04
# Epoch 28/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.9096 - loss: 0.6406 - val_accuracy: 0.8755 - val_loss: 0.7442 - learning_rate: 2.5000e-04
# Epoch 29/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.9197 - loss: 0.5989 - val_accuracy: 0.8668 - val_loss: 0.7726 - learning_rate: 2.5000e-04
# Epoch 30/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 310ms/step - accuracy: 0.9198 - loss: 0.6027 - val_accuracy: 0.8981 - val_loss: 0.6812 - learning_rate: 2.5000e-04
# Epoch 31/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.9233 - loss: 0.5813 - val_accuracy: 0.8856 - val_loss: 0.7126 - learning_rate: 2.5000e-04
# Epoch 32/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 310ms/step - accuracy: 0.9226 - loss: 0.5750 - val_accuracy: 0.8818 - val_loss: 0.6691 - learning_rate: 2.5000e-04
# Epoch 33/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 311ms/step - accuracy: 0.9173 - loss: 0.5781 - val_accuracy: 0.7755 - val_loss: 1.0671 - learning_rate: 2.5000e-04
# Epoch 34/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 142s 312ms/step - accuracy: 0.9267 - loss: 0.5535 - val_accuracy: 0.9018 - val_loss: 0.6430 - learning_rate: 2.5000e-04
# Epoch 35/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 310ms/step - accuracy: 0.9271 - loss: 0.5592 - val_accuracy: 0.9168 - val_loss: 0.5871 - learning_rate: 2.5000e-04
# Epoch 36/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 126s 316ms/step - accuracy: 0.9385 - loss: 0.5232 - val_accuracy: 0.8361 - val_loss: 0.9018 - learning_rate: 2.5000e-04
# Epoch 37/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 311ms/step - accuracy: 0.9271 - loss: 0.5501 - val_accuracy: 0.8343 - val_loss: 0.8716 - learning_rate: 2.5000e-04
# Epoch 38/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 310ms/step - accuracy: 0.9292 - loss: 0.5510 - val_accuracy: 0.7880 - val_loss: 1.1166 - learning_rate: 2.5000e-04
# Epoch 39/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 313ms/step - accuracy: 0.9383 - loss: 0.4999 - val_accuracy: 0.9149 - val_loss: 0.5705 - learning_rate: 2.5000e-04
# Epoch 40/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 141s 312ms/step - accuracy: 0.9423 - loss: 0.4924 - val_accuracy: 0.8868 - val_loss: 0.6593 - learning_rate: 2.5000e-04
# Epoch 41/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 124s 310ms/step - accuracy: 0.9354 - loss: 0.4890 - val_accuracy: 0.8568 - val_loss: 0.8274 - learning_rate: 2.5000e-04
# Epoch 42/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 312ms/step - accuracy: 0.9374 - loss: 0.4954 - val_accuracy: 0.8868 - val_loss: 0.6788 - learning_rate: 2.5000e-04
# Epoch 43/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9347 - loss: 0.4948
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 312ms/step - accuracy: 0.9347 - loss: 0.4948 - val_accuracy: 0.8893 - val_loss: 0.6636 - learning_rate: 2.5000e-04
# Epoch 44/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 313ms/step - accuracy: 0.9558 - loss: 0.4380 - val_accuracy: 0.8024 - val_loss: 1.0419 - learning_rate: 1.2500e-04
# Epoch 45/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 312ms/step - accuracy: 0.9582 - loss: 0.4267 - val_accuracy: 0.9118 - val_loss: 0.5596 - learning_rate: 1.2500e-04
# Epoch 46/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 312ms/step - accuracy: 0.9630 - loss: 0.3978 - val_accuracy: 0.9074 - val_loss: 0.5750 - learning_rate: 1.2500e-04
# Epoch 47/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 313ms/step - accuracy: 0.9563 - loss: 0.4151 - val_accuracy: 0.8605 - val_loss: 0.7990 - learning_rate: 1.2500e-04
# Epoch 48/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 313ms/step - accuracy: 0.9572 - loss: 0.4092 - val_accuracy: 0.9275 - val_loss: 0.5210 - learning_rate: 1.2500e-04
# Epoch 49/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 139s 347ms/step - accuracy: 0.9642 - loss: 0.3818 - val_accuracy: 0.9024 - val_loss: 0.6167 - learning_rate: 1.2500e-04
# Epoch 50/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 135s 338ms/step - accuracy: 0.9602 - loss: 0.3943 - val_accuracy: 0.9268 - val_loss: 0.5103 - learning_rate: 1.2500e-04
# Epoch 51/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 128s 320ms/step - accuracy: 0.9716 - loss: 0.3574 - val_accuracy: 0.9081 - val_loss: 0.5699 - learning_rate: 1.2500e-04
# Epoch 52/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 313ms/step - accuracy: 0.9687 - loss: 0.3546 - val_accuracy: 0.9300 - val_loss: 0.4813 - learning_rate: 1.2500e-04
# Epoch 53/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 313ms/step - accuracy: 0.9716 - loss: 0.3536 - val_accuracy: 0.9262 - val_loss: 0.5199 - learning_rate: 1.2500e-04
# Epoch 54/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 135s 337ms/step - accuracy: 0.9691 - loss: 0.3527 - val_accuracy: 0.9431 - val_loss: 0.4272 - learning_rate: 1.2500e-04
# Epoch 55/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 126s 314ms/step - accuracy: 0.9609 - loss: 0.3620 - val_accuracy: 0.8837 - val_loss: 0.6522 - learning_rate: 1.2500e-04
# Epoch 56/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 127s 318ms/step - accuracy: 0.9615 - loss: 0.3564 - val_accuracy: 0.8837 - val_loss: 0.6530 - learning_rate: 1.2500e-04
# Epoch 57/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 126s 314ms/step - accuracy: 0.9669 - loss: 0.3541 - val_accuracy: 0.8593 - val_loss: 0.7897 - learning_rate: 1.2500e-04
# Epoch 58/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9718 - loss: 0.3310
# Epoch 58: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 313ms/step - accuracy: 0.9718 - loss: 0.3310 - val_accuracy: 0.9043 - val_loss: 0.5527 - learning_rate: 1.2500e-04
# Epoch 59/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 126s 314ms/step - accuracy: 0.9707 - loss: 0.3219 - val_accuracy: 0.9575 - val_loss: 0.3734 - learning_rate: 6.2500e-05
# Epoch 60/60
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 125s 312ms/step - accuracy: 0.9738 - loss: 0.3066 - val_accuracy: 0.9256 - val_loss: 0.4987 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 59.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9585 - loss: 0.3690
#
#  Test Accuracy: 0.957
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        blues       0.94      0.97      0.96       155
#    classical       0.98      0.99      0.99       179
#      country       0.95      0.91      0.93       142
#        disco       0.97      0.95      0.96       149
#       hiphop       0.93      0.97      0.95       155
#         jazz       0.98      0.97      0.98       168
#        metal       0.94      0.97      0.95       180
#          pop       0.95      0.96      0.95       142
#       reggae       0.98      0.95      0.96       181
#         rock       0.94      0.92      0.93       148
#
#     accuracy                           0.96      1599
#    macro avg       0.96      0.96      0.96      1599
# weighted avg       0.96      0.96      0.96      1599
# /tmp/ipython-input-452549114.py:226: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=classes, y=acc_per_genre, palette='mako')
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#  Hybrid model and encoder saved successfully!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

#  Training and Validation Curves

def plot_training_history(history):
    # ---- Loss Curve ----
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
    plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    plt.title(' Training vs Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # ---- Accuracy Curve ----
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    plt.title(' Training vs Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()



# Confusion Matrix Visualization


def plot_confusion_matrix(model, X_test, y_test, classes):
    # Predict labels
    y_pred = model.predict(X_test)
    y_true = np.argmax(y_test, axis=1)
    y_pred = np.argmax(y_pred, axis=1)

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    # Plot heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_norm, annot=True, fmt=".2f", cmap="Blues",
                xticklabels=classes, yticklabels=classes)
    plt.title(" Normalized Confusion Matrix")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.tight_layout()
    plt.show()

# Run the Plots


plot_training_history(history)
plot_confusion_matrix(model, X_test, y_test, classes)
# Out:
# /tmp/ipython-input-992617294.py:20: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipython-input-992617294.py:32: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step
# /tmp/ipython-input-992617294.py:57: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

precision = []
recall = []
f1 = []

for cls in class_names:
    precision.append(report[cls]['precision'])
    recall.append(report[cls]['recall'])
    f1.append(report[cls]['f1-score'])


# 3. Compute per-class accuracy

cm = confusion_matrix(y_true, y_pred)
class_accuracy = cm.diagonal() / cm.sum(axis=1)

# 4. Plot grouped bar chart
x = np.arange(len(class_names))
width = 0.2

plt.figure(figsize=(14, 6))

plt.bar(x - 1.5*width, precision, width, label='Precision')
plt.bar(x - 0.5*width, recall, width, label='Recall')
plt.bar(x + 0.5*width, f1, width, label='F1-score')
plt.bar(x + 1.5*width, class_accuracy, width, label='Accuracy')

plt.xticks(x, class_names, rotation=45, ha='right')
plt.ylabel("Score")
plt.title("Per-Class Classification Metrics")
plt.legend()
plt.tight_layout()
plt.show()
